# %% [markdown]
# ### Import Statements

# %%
import json
import cv2
import numpy as np
from ultralytics import YOLO

# %% [markdown]
# ### Find Corners

# %%
def find_chessboard_corners(video_path, chessboard_size=(7, 7)):
    """
    Detect chessboard corners in the first frame of a video.

    Args:
        video_path (str): Path to the input video file.
        chessboard_size (tuple): Number of internal corners per chessboard row and column (rows, columns).

    Returns:
        bool: True if corners are found, False otherwise.
        numpy.ndarray: Coordinates of detected corners (if found).
        numpy.ndarray: The first frame with detected corners drawn.
    """
    # Open the video
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print("Error: Cannot open video file.")
        return False, None, None

    # Read the first frame from the video
    ret, frame = cap.read()
    cap.release()  # Release video resource
    if not ret:
        print("Error: Cannot read the first frame of the video.")
        return False, None, None

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Find chessboard corners
    found, corners = cv2.findChessboardCorners(gray_frame, chessboard_size, None)

    if found:
        # Define termination criteria
        criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
        # Refine corner locations
        corners = cv2.cornerSubPix(gray_frame, corners, (11, 11), (-1, -1), criteria)
        # Draw corners on the frame
        frame_with_corners = cv2.drawChessboardCorners(frame, chessboard_size, corners, found)
        return True, corners, frame_with_corners
    else:
        print("Chessboard corners not found.")
        return False, None, frame

# %% [markdown]
# ### Create JSON for Square positions

# %%
def map_positions_to_chessboard(corners, chessboard_size, output_json_path="chessboard_mapping.json"):
    """
    Map detected corner positions to squares on the chessboard and save the mapping to a JSON file.

    Args:
        corners (numpy.ndarray): Detected corner positions as a (N, 1, 2) array of points.
        chessboard_size (tuple): Number of internal corners per chessboard row and column (rows, columns).
        output_json_path (str): Path to save the chessboard mapping as a JSON file.

    Returns:
        dict: Mapping of chessboard squares to corner coordinates, e.g., {"A1": (x, y)}.
    """
    rows, cols = chessboard_size
    if len(corners) != rows * cols:
        raise ValueError("Number of detected corners does not match the expected chessboard size.")

    # Chessboard square mapping - bottom-left corner is A1
    chessboard_map = {}
    for row in range(rows):
        for col in range(cols):
            square = f"{chr(65 + col)}{row + 1}"  # Columns: A, B, C...; Rows: 1, 2, 3...
            index = row * cols + col
            position = tuple(map(float, corners[index, 0]))  # Convert numpy.float32 to float
            chessboard_map[square] = position

    # Save mapping - JSON 
    with open(output_json_path, "w") as json_file:
        json.dump(chessboard_map, json_file, indent=4)
    print(f"Chessboard mapping saved to {output_json_path}")

    return chessboard_map

# %% [markdown]
# ### Object Detection with YOLOv8 & Mapping of Pieces to Squares

# %%
def object_detection_with_mapping(input_video_path, output_video_path, model_path, board_mapping_path, output_mapping_json):
    """
    Perform object detection on a video, apply grayscale preprocessing, map detected objects to chessboard squares, and save the output.

    Args:
        input_video_path (str): Path to the input video.
        output_video_path (str): Path to save the output video.
        model_path (str): Path to the YOLO model file.
        board_mapping_path (str): Path to the JSON file containing chessboard mapping.
        output_mapping_json (str): Path to save the detected piece-square mappings as a JSON file.
    """
    # Load YOLO model
    model = YOLO(model_path)

    # Load chessboard mapping
    with open(board_mapping_path, "r") as f:
        board_mapping = json.load(f)

    # Open input video
    cap = cv2.VideoCapture(input_video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Define codec & create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Initialize list to store mappings 
    all_frame_mappings = []

    # Perform object detection and mapping
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Convert frame to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Perform detection with YOLOv8 on grayscale
        # YOLO expects a 3-channel image, so we need to convert back to BGR
        preprocessed_frame = cv2.cvtColor(gray_frame, cv2.COLOR_GRAY2BGR)

        results = model(preprocessed_frame)
        detections = results[0].boxes.data  # Access detected objects

        # Initialize a dictionary for detected pieces in the current frame
        frame_piece_positions = {}

        # Process each detection
        for detection in detections:
            # Extract bounding box & class
            x1, y1, x2, y2, confidence, class_id = detection.cpu().numpy()
            center_x, center_y = (x1 + x2) / 2, (y1 + y2) / 2  # Center of bounding box

            # Find nearest chessboard square
            nearest_square = None
            min_distance = float("inf")
            for square, position in board_mapping.items():
                mapped_x, mapped_y = position
                distance = ((center_x - mapped_x) ** 2 + (center_y - mapped_y) ** 2) ** 0.5
                if distance < min_distance:
                    min_distance = distance
                    nearest_square = square

            if nearest_square:
                piece_type = f"Class_{int(class_id)}"  # Placeholder for detected class label
                frame_piece_positions[nearest_square] = piece_type

        # Save frame piece positions to list
        all_frame_mappings.append(frame_piece_positions)

        # Print detected pieces & their positions
        for square, piece in frame_piece_positions.items():
            print(f"Detected {piece} at {square}")

        # Visualize detections on frame
        frame_with_detections = results[0].plot()

        # Write the frame with detections to the output video
        out.write(frame_with_detections)

    # Save frame mappings to JSON file
    with open(output_mapping_json, "w") as json_file:
        json.dump(all_frame_mappings, json_file, indent=4)
    print(f"Piece-square mappings saved to {output_mapping_json}")

    cap.release()
    out.release()
    print(f"Processed video saved at {output_video_path}")

# %%
# Set paths for read and save
video_path = r"C:\Users\robot\Documents\OD.mp4"
chessboard_size = (7, 7)  # Adjust to the dimensions of your chessboard
output_video_path = r"C:\Users\robot\Documents\Output\chess_game_output.mp4"
model_path = r"C:\Users\robot\Documents\Y8Run2\best.pt"  # Path to your trained YOLO model
board_mapping_path = r"C:\Users\robot\Documents\Output\chessboard_mapping.json"  # Path to pre-saved chessboard mapping JSON
output_mapping_json = r"C:\Users\robot\Documents\Output\detected_pieces.json"  # Path to save piece-square mappings

# Step 1: Detect corners in first frame of video
found, corners, annotated_frame = find_chessboard_corners(video_path, chessboard_size)

if found:
    # Step 2: Map positions to chessboard squares and save to JSON
    json_output_path = r"C:\Users\robot\Documents\Output\chessboard_mapping.json"
    chessboard_map = map_positions_to_chessboard(corners, chessboard_size, output_json_path=json_output_path)
    
    # Print mapping
    print("Chessboard mapping:")
    for square, position in chessboard_map.items():
        print(f"{square}: {position}")

    # Display the annotated frame
    cv2.imshow("Annotated Frame", annotated_frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Failed to detect chessboard corners.") # Debugging

# Step 3: Perform object detection & mapping
object_detection_with_mapping(video_path, output_video_path, model_path, board_mapping_path, output_mapping_json)
# Out:
# Chessboard mapping saved to C:\Users\robot\Documents\Output\chessboard_mapping.json
# Chessboard mapping:
# A1: (371.7565612792969, 312.5832824707031)
# B1: (375.4472961425781, 331.4908447265625)
# C1: (379.33587646484375, 351.5105895996094)
# D1: (383.2347106933594, 374.54345703125)
# E1: (387.7161560058594, 399.5608825683594)
# F1: (392.94830322265625, 427.5452880859375)
# G1: (399.3348083496094, 459.4858703613281)
# A2: (331.2346496582031, 310.6827087402344)
# B2: (332.52972412109375, 328.9006652832031)
# C2: (333.8887634277344, 349.56488037109375)
# D2: (335.9076843261719, 371.564453125)
# E2: (337.6922912597656, 397.1270446777344)
# F2: (340.52252197265625, 424.5157775878906)
# G2: (342.766845703125, 455.6446228027344)
# A3: (289.6357116699219, 308.562744140625)
# B3: (289.5288391113281, 327.39190673828125)
# C3: (289.442138671875, 347.6175842285156)
# D3: (289.021240234375, 369.7320556640625)
# E3: (288.2602233886719, 393.86895751953125)
# F3: (287.4859924316406, 421.7523193359375)
# G3: (287.10955810546875, 452.59649658203125)
ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 104.9ms
# Speed: 3.3ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 112.1ms
# Speed: 6.1ms preprocess, 112.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 90.0ms
# Speed: 3.0ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 66.9ms
# Speed: 2.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 74.3ms
# Speed: 3.0ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71.1ms
# Speed: 3.0ms preprocess, 71.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 62.9ms
# Speed: 4.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.4ms
# Speed: 3.0ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 79.8ms
# Speed: 2.0ms preprocess, 79.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 99.0ms
# Speed: 3.1ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 93.0ms
# Speed: 3.8ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 81.4ms
# Speed: 2.9ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 69.1ms
# Speed: 2.6ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 57.8ms
# Speed: 8.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 55.4ms
# Speed: 2.0ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.5ms
# Speed: 2.5ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71.9ms
# Speed: 2.0ms preprocess, 71.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 77.2ms
# Speed: 2.9ms preprocess, 77.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 78.9ms
# Speed: 2.1ms preprocess, 78.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 77.1ms
# Speed: 3.1ms preprocess, 77.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 76.2ms
# Speed: 2.8ms preprocess, 76.2ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 74.5ms
# Speed: 1.9ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 70.2ms
# Speed: 2.0ms preprocess, 70.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 57.4ms
# Speed: 2.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 85.0ms
# Speed: 8.0ms preprocess, 85.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.5ms
# Speed: 0.0ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 78.4ms
# Speed: 2.0ms preprocess, 78.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 89.0ms
# Speed: 0.0ms preprocess, 89.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 74.8ms
# Speed: 0.0ms preprocess, 74.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71.5ms
# Speed: 2.6ms preprocess, 71.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 386.8ms
# Speed: 2.0ms preprocess, 386.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 62.8ms
# Speed: 2.1ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.9ms
# Speed: 2.0ms preprocess, 60.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 61.5ms
# Speed: 1.9ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.9ms
# Speed: 2.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.7ms
# Speed: 2.7ms preprocess, 59.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 64.3ms
# Speed: 2.0ms preprocess, 64.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.5ms
# Speed: 1.6ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 61.3ms
# Speed: 2.0ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 80.3ms
# Speed: 0.0ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 76.7ms
# Speed: 0.0ms preprocess, 76.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 65.7ms
# Speed: 2.0ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 70.8ms
# Speed: 2.0ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71.2ms
# Speed: 0.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71.7ms
# Speed: 0.0ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 70.9ms
# Speed: 2.8ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 67.5ms
# Speed: 1.4ms preprocess, 67.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.2ms
# Speed: 1.9ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 68.0ms
# Speed: 16.1ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.5ms
# Speed: 2.1ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.9ms
# Speed: 2.0ms preprocess, 60.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 251.7ms
# Speed: 2.0ms preprocess, 251.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 75.9ms
# Speed: 31.1ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 61.7ms
# Speed: 0.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 65.1ms
# Speed: 3.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.7ms
# Speed: 1.0ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.8ms
# Speed: 3.0ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 64.2ms
# Speed: 2.0ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 84.8ms
# Speed: 0.0ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 66.7ms
# Speed: 2.0ms preprocess, 66.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 74.3ms
# Speed: 5.0ms preprocess, 74.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.9ms
# Speed: 7.2ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 76.3ms
# Speed: 1.7ms preprocess, 76.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 67.4ms
# Speed: 2.4ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 306.5ms
# Speed: 2.0ms preprocess, 306.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.0ms
# Speed: 2.2ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 66.8ms
# Speed: 3.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 80.6ms
# Speed: 2.0ms preprocess, 80.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 64.3ms
# Speed: 0.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 58.2ms
# Speed: 1.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 85.5ms
# Speed: 4.0ms preprocess, 85.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 75.9ms
# Speed: 8.2ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 81.5ms
# Speed: 2.9ms preprocess, 81.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 79.4ms
# Speed: 3.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 85.9ms
# Speed: 3.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 82.9ms
# Speed: 2.3ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 74.5ms
# Speed: 2.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 72.9ms
# Speed: 2.0ms preprocess, 72.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 74.4ms
# Speed: 2.0ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 76.9ms
# Speed: 2.0ms preprocess, 76.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 85.0ms
# Speed: 0.0ms preprocess, 85.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 96.9ms
# Speed: 2.0ms preprocess, 96.9ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 98.4ms
# Speed: 8.0ms preprocess, 98.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 100.4ms
# Speed: 2.0ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 87.9ms
# Speed: 2.0ms preprocess, 87.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 77.3ms
# Speed: 0.0ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 80.1ms
# Speed: 2.2ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 91.4ms
# Speed: 3.9ms preprocess, 91.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 86.6ms
# Speed: 3.0ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 75.2ms
# Speed: 3.0ms preprocess, 75.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 87.3ms
# Speed: 2.0ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 424.5ms
# Speed: 2.1ms preprocess, 424.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# ...
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 83.3ms
# Speed: 2.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 67.4ms
# Speed: 4.1ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 62.7ms
# Speed: 2.0ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 65.5ms
# Speed: 0.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 73.0ms
# Speed: 4.3ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 360.7ms
# Speed: 3.0ms preprocess, 360.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-rook, 142.0ms
# Speed: 3.0ms preprocess, 142.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 66.9ms
# Speed: 3.0ms preprocess, 66.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 65.8ms
# Speed: 9.3ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 81.1ms
# Speed: 0.0ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 59.6ms
# Speed: 3.2ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 71.3ms
# Speed: 2.0ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 73.3ms
# Speed: 2.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 58.9ms
# Speed: 3.0ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 77.7ms
# Speed: 3.0ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 74.7ms
# Speed: 3.7ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 102.0ms
# Speed: 1.7ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 363.3ms
# Speed: 2.8ms preprocess, 363.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 132.9ms
# Speed: 3.1ms preprocess, 132.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 58.1ms
# Speed: 0.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 78.6ms
# Speed: 2.0ms preprocess, 78.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 88.9ms
# Speed: 0.0ms preprocess, 88.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 72.9ms
# Speed: 2.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 63.9ms
# Speed: 2.6ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 84.3ms
# Speed: 0.0ms preprocess, 84.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 85.0ms
# Speed: 2.1ms preprocess, 85.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 78.6ms
# Speed: 3.1ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 66.6ms
# Speed: 2.0ms preprocess, 66.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 385.6ms
# Speed: 2.5ms preprocess, 385.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 140.8ms
# Speed: 3.0ms preprocess, 140.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-queen, 1 white-rook, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-rook, 72.2ms
# Speed: 2.0ms preprocess, 72.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 70.8ms
# Speed: 2.0ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-queen, 1 white-rook, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-rook, 80.6ms
# Speed: 0.0ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 64.7ms
# Speed: 1.9ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 60.2ms
# Speed: 2.0ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-rook, 63.7ms
# Speed: 3.0ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-queen, 1 white-rook, 63.7ms
# Speed: 9.1ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 58.9ms
# Speed: 1.0ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 69.9ms
# Speed: 2.0ms preprocess, 69.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 59.4ms
# Speed: 1.5ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 339.2ms
# Speed: 2.0ms preprocess, 339.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 137.4ms
# Speed: 2.0ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 60.9ms
# Speed: 0.0ms preprocess, 60.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 67.9ms
# Speed: 2.2ms preprocess, 67.9ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 73.5ms
# Speed: 2.0ms preprocess, 73.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 62.9ms
# Speed: 2.7ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 67.7ms
# Speed: 0.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 63.8ms
# Speed: 1.5ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 67.4ms
# Speed: 2.0ms preprocess, 67.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-queen, 1 white-rook, 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
#
# 0: 640x384 1 white-rook, 59.0ms
# Speed: 0.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
#
# 0: 640x384 1 white-queen, 1 white-rook, 76.0ms
# Speed: 2.8ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Detected Class_12 at F1
# Detected Class_11 at E2
# Piece-square mappings saved to C:\Users\robot\Documents\Output\detected_pieces.json
# Processed video saved at C:\Users\robot\Documents\Output\chess_game_output.mp4
